# %% [raw]
# IMPORTS AND DATA LOADING

# %%
import pandas as pd
import json
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from transformers import BertTokenizer, TFBertForSequenceClassification
import tensorflow as tf

# %%
# Load the data from a file
with open('/Users/bishalthapa/Desktop/2024/Deep Learning/Project/Code/DeepLearningProject/clinc150_uci/data_full.json', 'r') as file:
    data = json.load(file)
    # print(data)

# %%
# Convert lists to DataFrames
train_df = pd.DataFrame(data['train'], columns=['text', 'intent'])
val_df = pd.DataFrame(data['val'], columns=['text', 'intent'])
test_df = pd.DataFrame(data['test'], columns=['text', 'intent'])
oos_train_df=pd.DataFrame(data['oos_train'],columns=['text','intent'])
oos_test_df=pd.DataFrame(data['oos_test'],columns=['text','intent'])
oos_val_df=pd.DataFrame(data['oos_val'],columns=['text','intent'])

# %%
oos_test_df
# Out:
#                                                   text intent
# 0                   how much has the dow changed today    oos
# 1    how many prime numbers are there between 0 and...    oos
# 2    can you tell me how to solve simple algebraic ...    oos
# 3              can you dim the brightness of my screen    oos
# 4    what is the account number to the internet ser...    oos
# ..                                                 ...    ...
# 995                                     find my wallet    oos
# 996         can you give me the gps location of harvey    oos
# 997           where's my buddy steve right this second    oos
# 998               locate jenny at her present position    oos
# 999                 let me know where jim is right now    oos
#
# [1000 rows x 2 columns]

# %%
# Prepare the tokenizer for LSTM
lstm_tokenizer = Tokenizer(num_words=10000)  
lstm_tokenizer.fit_on_texts(train_df['text'])

# %%
# Preprocess the data for LSTM
max_length = 100  
train_sequences = lstm_tokenizer.texts_to_sequences(train_df['text'])
train_sequences_padded = pad_sequences(train_sequences, maxlen=max_length)

# %%
train_sequences_padded
# Out:
# array([[   0,    0,    0, ...,  201,   48,  503],
#        [   0,    0,    0, ..., 2853,   15,  401],
#        [   0,    0,    0, ..., 2856,   15,  301],
#        ...,
#        [   0,    0,    0, ...,  118,  979,  396],
#        [   0,    0,    0, ...,   25,  231,  396],
#        [   0,    0,    0, ...,  231,   26, 1507]], dtype=int32)

# %%
val_sequences = lstm_tokenizer.texts_to_sequences(val_df['text'])
val_sequences_padded = pad_sequences(val_sequences, maxlen=max_length)

# %%
# Creating a set of all possible labels including in-domain and 'oos'
all_labels = set(train_df['intent']).union(set(val_df['intent']), set(test_df['intent']), ['oos'])

# Creating a label index mapping every label to an integer
label_index = {label: idx for idx, label in enumerate(all_labels)}

# %%
label_index
# Out:
# {'transactions': 0,
#  'pto_request': 1,
#  'order_status': 2,
#  'report_lost_card': 3,
#  'carry_on': 4,
#  'report_fraud': 5,
#  'what_is_your_name': 6,
#  'change_accent': 7,
#  'cook_time': 8,
#  'restaurant_suggestion': 9,
#  'date': 10,
#  'current_location': 11,
#  'rollover_401k': 12,
#  'pto_used': 13,
#  'weather': 14,
#  'share_location': 15,
#  'goodbye': 16,
#  'directions': 17,
#  'calculator': 18,
#  'who_made_you': 19,
#  'income': 20,
#  'mpg': 21,
#  'who_do_you_work_for': 22,
#  'improve_credit_score': 23,
#  'apr': 24,
#  'todo_list': 25,
#  'expiration_date': 26,
#  'calendar_update': 27,
#  'freeze_account': 28,
#  'interest_rate': 29,
#  'make_call': 30,
#  'balance': 31,
#  'calendar': 32,
#  'shopping_list': 33,
#  'how_busy': 34,
#  'travel_alert': 35,
#  'spelling': 36,
#  'shopping_list_update': 37,
#  'user_name': 38,
#  'application_status': 39,
#  'sync_device': 40,
#  'meal_suggestion': 41,
#  'min_payment': 42,
#  'schedule_maintenance': 43,
#  'pto_request_status': 44,
#  'last_maintenance': 45,
#  'flip_coin': 46,
#  'transfer': 47,
#  'oil_change_how': 48,
#  'account_blocked': 49,
#  'tire_change': 50,
#  'recipe': 51,
#  'oil_change_when': 52,
#  'meaning_of_life': 53,
#  'smart_home': 54,
#  'exchange_rate': 55,
#  'translate': 56,
#  'card_declined': 57,
#  'car_rental': 58,
#  'where_are_you_from': 59,
#  'nutrition_info': 60,
#  'redeem_rewards': 61,
#  'next_song': 62,
#  'whisper_mode': 63,
#  'vaccines': 64,
#  'change_language': 65,
#  'next_holiday': 66,
#  'change_user_name': 67,
#  'timezone': 68,
#  'what_are_your_hobbies': 69,
#  'measurement_conversion': 70,
#  'schedule_meeting': 71,
#  'timer': 72,
#  'what_song': 73,
#  'credit_score': 74,
#  'thank_you': 75,
#  'book_hotel': 76,
#  'are_you_a_bot': 77,
#  'direct_deposit': 78,
#  'no': 79,
#  'reset_settings': 80,
#  'yes': 81,
#  'distance': 82,
#  'change_speed': 83,
#  'taxes': 84,
#  'spending_history': 85,
#  'credit_limit': 86,
#  'ingredients_list': 87,
#  'tell_joke': 88,
#  'do_you_have_pets': 89,
#  'restaurant_reservation': 90,
#  'repeat': 91,
#  'ingredient_substitution': 92,
#  'cancel': 93,
#  'find_phone': 94,
#  'time': 95,
#  'traffic': 96,
#  'pin_change': 97,
#  'restaurant_reviews': 98,
#  'book_flight': 99,
#  'fun_fact': 100,
#  'lost_luggage': 101,
#  'uber': 102,
#  'travel_suggestion': 103,
#  'credit_limit_change': 104,
#  'bill_balance': 105,
#  'greeting': 106,
#  'change_ai_name': 107,
#  'text': 108,
#  'gas_type': 109,
#  'gas': 110,
#  'update_playlist': 111,
#  'todo_list_update': 112,
#  'reminder_update': 113,
#  'pay_bill': 114,
#  'change_volume': 115,
#  'flight_status': 116,
#  'pto_balance': 117,
#  'food_last': 118,
#  'how_old_are_you': 119,
#  'travel_notification': 120,
#  'maybe': 121,
#  'accept_reservations': 122,
#  'confirm_reservation': 123,
#  'tire_pressure': 124,
#  'payday': 125,
#  'damaged_card': 126,
#  'bill_due': 127,
#  'calories': 128,
#  'insurance_change': 129,
#  'play_music': 130,
#  'new_card': 131,
#  'international_fees': 132,
#  'jump_start': 133,
#  'reminder': 134,
#  'rewards_balance': 135,
#  'replacement_card_duration': 136,
#  'order': 137,
#  'cancel_reservation': 138,
#  'what_can_i_ask_you': 139,
#  'roll_dice': 140,
#  'routing': 141,
#  'plug_type': 142,
#  'order_checks': 143,
#  'insurance': 144,
#  'oos': 145,
#  'meeting_schedule': 146,
#  'w2': 147,
#  'alarm': 148,
#  'international_visa': 149,
#  'definition': 150}

# %%
def encode_labels(labels, label_index):
    # Map labels to their respective index
    label_indices = [label_index[label] for label in labels]
    # Encode labels as one-hot vectors
    return to_categorical(label_indices, num_classes=len(label_index))

# Encoding labels for all datasets
train_labels = encode_labels(train_df['intent'], label_index)
val_labels = encode_labels(val_df['intent'], label_index)
oos_train_labels = encode_labels(['oos'] * len(oos_train_df), label_index)
oos_val_labels = encode_labels(['oos'] * len(oos_val_df), label_index)
oos_test_labels = encode_labels(['oos'] * len(oos_test_df), label_index)

# %%
# Build and compile the LSTM model
lstm_model = Sequential()
lstm_model.add(Embedding(input_dim=10000, output_dim=128, input_length=max_length))
lstm_model.add(LSTM(units=64))
lstm_model.add(Dense(len(label_index), activation='softmax'))
lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:86: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Train the LSTM model
lstm_model.fit(train_sequences_padded, train_labels, batch_size=128, epochs=10, validation_data=(val_sequences_padded, val_labels))
# Out:
# Epoch 1/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - accuracy: 0.0460 - loss: 4.9163 - val_accuracy: 0.2727 - val_loss: 3.8160
# Epoch 2/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.4932 - loss: 3.1336 - val_accuracy: 0.7310 - val_loss: 1.9714
# Epoch 3/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.8414 - loss: 1.4398 - val_accuracy: 0.8237 - val_loss: 1.1819
# Epoch 4/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.9271 - loss: 0.7288 - val_accuracy: 0.8590 - val_loss: 0.8516
# Epoch 5/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.9558 - loss: 0.4258 - val_accuracy: 0.8717 - val_loss: 0.6927
# Epoch 6/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 96ms/step - accuracy: 0.9734 - loss: 0.2883 - val_accuracy: 0.8797 - val_loss: 0.6107
# Epoch 7/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.9812 - loss: 0.2052 - val_accuracy: 0.8813 - val_loss: 0.5627
# Epoch 8/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step - accuracy: 0.9854 - loss: 0.1521 - val_accuracy: 0.8800 - val_loss: 0.5331
# Epoch 9/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 95ms/step - accuracy: 0.9890 - loss: 0.1180 - val_accuracy: 0.8860 - val_loss: 0.5128
# Epoch 10/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 104ms/step - accuracy: 0.9928 - loss: 0.0907 - val_accuracy: 0.8833 - val_loss: 0.5034

# %%
# Additional preprocessing for the out-of-sample data
oos_train_sequences = lstm_tokenizer.texts_to_sequences(oos_train_df['text'])
oos_train_sequences_padded = pad_sequences(oos_train_sequences, maxlen=max_length)

oos_val_sequences = lstm_tokenizer.texts_to_sequences(oos_val_df['text'])
oos_val_sequences_padded = pad_sequences(oos_val_sequences, maxlen=max_length)

oos_test_sequences = lstm_tokenizer.texts_to_sequences(oos_test_df['text'])
oos_test_sequences_padded = pad_sequences(oos_test_sequences, maxlen=max_length)

# %%
oos_test_sequences_padded
# Out:
# array([[   0,    0,    0, ...,    4,  178,  126],
#        [   0,    0,    0, ...,  170,   27,  743],
#        [   0,    0,    0, ..., 5098,   43,   93],
#        ...,
#        [   0,    0,    0, ...,  130,   41, 1084],
#        [   0,    0,    0, ...,  721,  981, 2189],
#        [   0,    0,    0, ...,   10,  130,   73]], dtype=int32)

# %%
# Create an additional 'oos' or 'unknown' label for out-of-sample data
oos_label = 'oos'
if oos_label not in label_index:
    label_index[oos_label] = len(label_index)

# %%
# Combine in-domain and out-of-sample training data
combined_train_sequences_padded = np.concatenate([train_sequences_padded, oos_train_sequences_padded])
combined_train_labels = np.concatenate([train_labels, oos_train_labels])

# %%
combined_val_sequences_padded = np.concatenate([val_sequences_padded, oos_val_sequences_padded])
combined_val_labels = np.concatenate([val_labels, oos_val_labels])
lstm_model.evaluate(combined_val_sequences_padded, combined_val_labels)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8790 - loss: 0.5086
# [0.8467375636100769, 0.8548387289047241]

# %%
# Train the model
lstm_model.fit(combined_train_sequences_padded, combined_train_labels, batch_size=128, epochs=10, validation_data=(combined_val_sequences_padded, combined_val_labels))

# Evaluate on the test set
lstm_model.evaluate(oos_test_sequences_padded, oos_test_labels)
# Out:
# Epoch 1/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 13s 108ms/step - accuracy: 0.9868 - loss: 0.1437 - val_accuracy: 0.8571 - val_loss: 0.6668
# Epoch 2/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step - accuracy: 0.9904 - loss: 0.0871 - val_accuracy: 0.8626 - val_loss: 0.5853
# Epoch 3/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 13s 106ms/step - accuracy: 0.9944 - loss: 0.0640 - val_accuracy: 0.8661 - val_loss: 0.5692
# Epoch 4/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - accuracy: 0.9969 - loss: 0.0503 - val_accuracy: 0.8623 - val_loss: 0.5652
# Epoch 5/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - accuracy: 0.9975 - loss: 0.0428 - val_accuracy: 0.8648 - val_loss: 0.5696
# Epoch 6/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 100ms/step - accuracy: 0.9980 - loss: 0.0362 - val_accuracy: 0.8645 - val_loss: 0.5682
# Epoch 7/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 94ms/step - accuracy: 0.9985 - loss: 0.0302 - val_accuracy: 0.8600 - val_loss: 0.5627
# Epoch 8/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 89ms/step - accuracy: 0.9982 - loss: 0.0275 - val_accuracy: 0.8613 - val_loss: 0.5657
# Epoch 9/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.9988 - loss: 0.0235 - val_accuracy: 0.8574 - val_loss: 0.5697
# Epoch 10/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.9992 - loss: 0.0199 - val_accuracy: 0.8594 - val_loss: 0.5773
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3115 - loss: 3.6030
# [3.7823197841644287, 0.289000004529953]

# %%
lstm_model.evaluate(oos_test_sequences_padded, oos_test_labels)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3115 - loss: 3.6030
# [3.7823197841644287, 0.289000004529953]

# %% [raw]
# # CONFUSION MATRIX FOR ALL CLASSES

# %%
# Predict classes with LSTM model on the validation set
val_predictions = lstm_model.predict(val_sequences_padded)
val_predictions_classes = np.argmax(val_predictions, axis=1)
true_val_classes = np.argmax(val_labels, axis=1)

# Create the confusion matrix
cm = confusion_matrix(true_val_classes, val_predictions_classes)

# Generate a classification report
report = classification_report(true_val_classes, val_predictions_classes, target_names=list(label_index.keys()))

print("Classification Report:\n", report)

# Plotting the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=list(label_index.keys()), yticklabels=list(label_index.keys()))
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Classification Report:
#                             precision    recall  f1-score   support
#
#              transactions       0.93      0.70      0.80        20
#               pto_request       0.95      0.95      0.95        20
#              order_status       0.71      0.75      0.73        20
#          report_lost_card       0.90      0.95      0.93        20
#                  carry_on       0.95      0.90      0.92        20
#              report_fraud       0.95      0.95      0.95        20
#         what_is_your_name       0.76      0.95      0.84        20
#             change_accent       1.00      0.70      0.82        20
#                 cook_time       0.91      1.00      0.95        20
#     restaurant_suggestion       0.59      0.65      0.62        20
#                      date       0.74      0.85      0.79        20
#          current_location       0.67      0.80      0.73        20
#             rollover_401k       1.00      1.00      1.00        20
#                  pto_used       0.88      0.75      0.81        20
#                   weather       1.00      0.85      0.92        20
#            share_location       0.94      0.75      0.83        20
#                   goodbye       0.55      0.90      0.68        20
#                directions       0.95      0.95      0.95        20
#                calculator       1.00      0.75      0.86        20
#              who_made_you       1.00      0.80      0.89        20
#                    income       0.71      0.85      0.77        20
#                       mpg       1.00      1.00      1.00        20
#       who_do_you_work_for       0.86      0.95      0.90        20
#      improve_credit_score       1.00      0.85      0.92        20
#                       apr       0.86      0.95      0.90        20
#                 todo_list       0.62      0.80      0.70        20
#           expiration_date       0.94      0.75      0.83        20
#           calendar_update       0.90      0.90      0.90        20
#            freeze_account       0.64      0.90      0.75        20
#             interest_rate       0.95      1.00      0.98        20
#                 make_call       0.83      1.00      0.91        20
#                   balance       0.94      0.80      0.86        20
#                  calendar       0.84      0.80      0.82        20
#             shopping_list       0.83      1.00      0.91        20
#                  how_busy       0.91      1.00      0.95        20
#              travel_alert       0.90      0.90      0.90        20
#                  spelling       1.00      1.00      1.00        20
#      shopping_list_update       1.00      0.85      0.92        20
#                 user_name       0.76      0.95      0.84        20
#        application_status       0.95      0.95      0.95        20
#               sync_device       1.00      1.00      1.00        20
#           meal_suggestion       1.00      0.80      0.89        20
#               min_payment       0.91      1.00      0.95        20
#      schedule_maintenance       0.77      0.85      0.81        20
#        pto_request_status       0.83      0.75      0.79        20
#          last_maintenance       0.85      0.85      0.85        20
#                 flip_coin       1.00      1.00      1.00        20
#                  transfer       0.90      0.90      0.90        20
#            oil_change_how       0.90      0.90      0.90        20
#           account_blocked       0.88      0.70      0.78        20
#               tire_change       0.91      1.00      0.95        20
#                    recipe       0.80      0.80      0.80        20
#           oil_change_when       0.82      0.90      0.86        20
#           meaning_of_life       0.74      0.85      0.79        20
#                smart_home       0.91      1.00      0.95        20
#             exchange_rate       0.95      0.90      0.92        20
#                 translate       0.89      0.85      0.87        20
#             card_declined       1.00      0.95      0.97        20
#                car_rental       0.83      1.00      0.91        20
#        where_are_you_from       0.81      0.85      0.83        20
#            nutrition_info       1.00      0.45      0.62        20
#            redeem_rewards       0.86      0.90      0.88        20
#                 next_song       0.91      1.00      0.95        20
#              whisper_mode       0.91      1.00      0.95        20
#                  vaccines       0.95      0.90      0.92        20
#           change_language       0.75      0.90      0.82        20
#              next_holiday       0.86      0.95      0.90        20
#          change_user_name       0.77      0.50      0.61        20
#                  timezone       1.00      0.90      0.95        20
#     what_are_your_hobbies       0.94      0.85      0.89        20
#    measurement_conversion       0.94      0.80      0.86        20
#          schedule_meeting       0.91      1.00      0.95        20
#                     timer       1.00      1.00      1.00        20
#                 what_song       0.83      0.95      0.88        20
#              credit_score       0.86      0.95      0.90        20
#                 thank_you       0.95      1.00      0.98        20
#                book_hotel       0.89      0.85      0.87        20
#             are_you_a_bot       0.95      0.95      0.95        20
#            direct_deposit       0.95      1.00      0.98        20
#                        no       0.94      0.75      0.83        20
#            reset_settings       0.91      1.00      0.95        20
#                       yes       0.88      0.70      0.78        20
#                  distance       0.94      0.85      0.89        20
#              change_speed       1.00      0.95      0.97        20
#                     taxes       0.86      0.90      0.88        20
#          spending_history       0.83      1.00      0.91        20
#              credit_limit       0.86      0.90      0.88        20
#          ingredients_list       0.95      0.90      0.92        20
#                 tell_joke       0.91      1.00      0.95        20
#          do_you_have_pets       1.00      0.85      0.92        20
#    restaurant_reservation       0.74      0.70      0.72        20
#                    repeat       0.81      0.85      0.83        20
#   ingredient_substitution       1.00      0.80      0.89        20
#                    cancel       0.83      0.75      0.79        20
#                find_phone       1.00      0.90      0.95        20
#                      time       0.83      0.95      0.88        20
#                   traffic       1.00      0.95      0.97        20
#                pin_change       1.00      1.00      1.00        20
#        restaurant_reviews       0.83      0.50      0.62        20
#               book_flight       1.00      0.75      0.86        20
#                  fun_fact       1.00      1.00      1.00        20
#              lost_luggage       1.00      1.00      1.00        20
#                      uber       1.00      0.90      0.95        20
#         travel_suggestion       0.68      0.75      0.71        20
#       credit_limit_change       1.00      0.90      0.95        20
#              bill_balance       1.00      0.85      0.92        20
#                  greeting       0.63      0.85      0.72        20
#            change_ai_name       0.87      0.65      0.74        20
#                      text       0.94      0.75      0.83        20
#                  gas_type       0.91      1.00      0.95        20
#                       gas       0.89      0.85      0.87        20
#           update_playlist       1.00      0.65      0.79        20
#          todo_list_update       0.83      0.75      0.79        20
#           reminder_update       0.95      0.95      0.95        20
#                  pay_bill       1.00      0.85      0.92        20
#             change_volume       1.00      0.95      0.97        20
#             flight_status       1.00      1.00      1.00        20
#               pto_balance       0.82      0.90      0.86        20
#                 food_last       0.94      0.80      0.86        20
#           how_old_are_you       0.82      0.90      0.86        20
#       travel_notification       0.93      0.70      0.80        20
#                     maybe       0.89      0.85      0.87        20
#       accept_reservations       0.93      0.65      0.76        20
#       confirm_reservation       0.88      0.70      0.78        20
#             tire_pressure       1.00      0.95      0.97        20
#                    payday       0.93      0.65      0.76        20
#              damaged_card       0.85      0.85      0.85        20
#                  bill_due       0.83      1.00      0.91        20
#                  calories       0.95      1.00      0.98        20
#          insurance_change       0.86      0.95      0.90        20
#                play_music       0.80      0.80      0.80        20
#                  new_card       0.89      0.80      0.84        20
#        international_fees       0.90      0.95      0.93        20
#                jump_start       1.00      1.00      1.00        20
#                  reminder       0.88      0.70      0.78        20
#           rewards_balance       0.83      1.00      0.91        20
# replacement_card_duration       0.74      0.85      0.79        20
#                     order       0.78      0.70      0.74        20
#        cancel_reservation       0.83      1.00      0.91        20
#        what_can_i_ask_you       0.71      1.00      0.83        20
#                 roll_dice       1.00      0.95      0.97        20
#                   routing       1.00      1.00      1.00        20
#                 plug_type       1.00      0.80      0.89        20
#              order_checks       0.86      0.90      0.88        20
#                 insurance       0.90      0.90      0.90        20
#                       oos       0.00      0.00      0.00         0
#          meeting_schedule       0.91      1.00      0.95        20
#                        w2       0.95      0.95      0.95        20
#                     alarm       0.95      0.95      0.95        20
#        international_visa       0.95      0.90      0.92        20
#                definition       0.94      0.80      0.86        20
#
#                  accuracy                           0.88      3000
#                 macro avg       0.89      0.87      0.87      3000
#              weighted avg       0.89      0.88      0.88      3000
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## ROC AUC FOR FEW CLASSES

# %%
from sklearn.metrics import precision_recall_curve, auc
from sklearn.preprocessing import label_binarize


# For precision-recall curve, you need binarized labels
binarized_val_labels = label_binarize(true_val_classes, classes=range(len(label_index)))

# Calculate precision and recall
precision = dict()
recall = dict()
for i in range(len(label_index)):
    precision[i], recall[i], _ = precision_recall_curve(binarized_val_labels[:, i],
                                                        val_predictions[:, i])

# Plot the precision-recall curve for each class
for i, color in zip(range(len(label_index)), "bgrcmykw"):
    plt.plot(recall[i], precision[i], color=color, lw=2,
             label='Class {0} (area = {1:0.2f})'.format(list(label_index.keys())[i], auc(recall[i], precision[i])))

plt.gca().invert_xaxis()  # Inverts the x-axis
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve for each class')
plt.legend(loc="lower right")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
# Generate predictions for combined validation dataset 
combined_val_predictions = lstm_model.predict(combined_val_sequences_padded)
combined_val_predictions_classes = np.argmax(combined_val_predictions, axis=1)  # Get the index of the max logit
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step

# %%
## CHANGING ALL IN_DOMAIN CLASSES AS 0 AND OUT-OF-DOMAIN AS 1 FOR SIMPLER CONFUSION MATRIX

# %%
# Convert multi-class labels to binary labels (0 for in-domain, 1 for out-of-domain)
def convert_to_binary(classes, oos_index):
    return [0 if class_index != oos_index else 1 for class_index in classes]

# Assuming `oos_index` is the index of 'oos' in label_index
oos_index = label_index['oos']

# Convert true labels for validation
binary_true_val_labels = convert_to_binary(np.argmax(combined_val_labels, axis=1), oos_index)

# Assuming you've made predictions with the model
val_predictions = lstm_model.predict(combined_val_sequences_padded)
binary_predicted_val_labels = convert_to_binary(np.argmax(val_predictions, axis=1), oos_index)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(binary_true_val_labels, binary_predicted_val_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['In-domain', 'Out-of-domain'], yticklabels=['In-domain', 'Out-of-domain'])
plt.title('Confusion Matrix for Classification')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification report for precision, recall, F1-score
report = classification_report(binary_true_val_labels, binary_predicted_val_labels, target_names=['In-domain', 'Out-of-domain'])
print(report)
# Out:
#                precision    recall  f1-score   support
#
#     In-domain       0.98      0.99      0.98      3000
# Out-of-domain       0.57      0.39      0.46       100
#
#      accuracy                           0.97      3100
#     macro avg       0.77      0.69      0.72      3100
#  weighted avg       0.97      0.97      0.97      3100

# %%
fpr, tpr, thresholds = roc_curve(binary_true_val_labels, val_predictions[:, oos_index])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
